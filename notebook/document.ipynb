# %% [markdown]
# Data Ingestion

# %%
from langchain_core.documents import Document

# %%
doc=Document(page_content="Hello, world! This is my first document", metadata={"source": "example.com", "author": "SnehaUppula"})
doc
# Out:
# Document(metadata={'source': 'example.com', 'author': 'SnehaUppula'}, page_content='Hello, world! This is my first document')

# %% [markdown]
# this metadata is helpful for the RAG pipeline to understand the document and used in filtering the documents
# ex- if we want to filter the documents by the author

# %%
#creating the text files
import os
os.makedirs('../data/text_files', exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}
for file_path, text in sample_texts.items():
    with open(file_path, 'w') as f:
        f.write(text)
    print(f"File {file_path} created successfully.")
# Out:
# File ../data/text_files/python_intro.txt created successfully.
# File ../data/text_files/machine_learning.txt created successfully.

# %%
#loading the text file
from langchain_community.document_loaders import TextLoader
loader=TextLoader('../data/text_files/python_intro.txt')
data=loader.load()
print(data)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
loader2=TextLoader('../data/text_files/machine_learning.txt')
data2=loader2.load()
print(data2)
# Out:
# [Document(metadata={'source': '../data/text_files/machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    ')]

# %%
# loading the whole directory (DirectoryLoader: `glob` + optional `recursive`, not glob_pattern)
from langchain_community.document_loaders import DirectoryLoader, TextLoader

loader = DirectoryLoader(
    "../data/text_files",
    glob="*.txt",
    loader_cls=TextLoader,
    recursive=True,
)
data = loader.load()
print(data)
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    '), Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most pop
# ...

# %%
#loading the pdf(using pypdfloaader)
from langchain_community.document_loaders import PyPDFLoader,PyMuPDFLoader
loader = DirectoryLoader(
    "../data/pdf/",
    glob="*.pdf",
    loader_cls=PyPDFLoader,
    recursive=True,
)
data = loader.load()
print(data)
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-04-13T19:09:05+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-04-13T19:09:05+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': '..\\data\\pdf\\Claude_research_paper.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Claude AI: A Detailed Overview\nAbstract\nClaude is a family of large language models developed by Anthropic. It is designed to be helpful,\nhonest, and harmless, focusing on safety and alignment in AI systems.\n1. Introduction\nClaude is named after Claude Shannon, a pioneer of information theory. It is built to assist users in\ntasks such as writing, coding, and reasoning.\nAnthropic focuses on creating AI systems that align with human values.\n2. Key Features\nClaude offers: - Strong reasoning abilities - Long context handling - Safer and more controlled\nresponses - High-
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader,PyMuPDFLoader
loader = DirectoryLoader(
    "../data/pdf/",
    glob="*.pdf",
    loader_cls=PyMuPDFLoader,
    recursive=True,
)
data = loader.load()
print(data)
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-04-13T19:09:05+00:00', 'source': '..\\data\\pdf\\Claude_research_paper.pdf', 'file_path': '..\\data\\pdf\\Claude_research_paper.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-04-13T19:09:05+00:00', 'trapped': '', 'modDate': "D:20260413190905+00'00'", 'creationDate': "D:20260413190905+00'00'", 'page': 0}, page_content='Claude AI: A Detailed Overview\nAbstract\nClaude is a family of large language models developed by Anthropic. It is designed to be helpful,\nhonest, and harmless, focusing on safety and alignment in AI systems.\n1. Introduction\nClaude is named after Claude Shannon, a pioneer of information theory. It is built to assist users in\ntasks such as writing, coding, and reasoning.\nAnthropic focuses on creating AI systems that align with human values
# ...

# %% [markdown]
# pypdf is pure Python and best for light PDF work (merge/split, metadata, simple text). PyMuPDF uses a fast native engine and is better for tricky layouts, richer text extraction, and turning pages into images. Use pypdf when “good enough” and small deps matter; use PyMuPDF when quality or rendering matters—and check its license for how you ship the app.
